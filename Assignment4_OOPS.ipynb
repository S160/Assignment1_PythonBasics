# %% [markdown]
# Ans 1: Object-Oriented Programming (OOP) is a programming type based on the concept of “objects”, which can contain data (in the form of fields or attributes) and code (in the form of methods or functions). OOP helps structure programs so that properties and behaviors are bundled into individual objects.
# It provides encapsulation, abstraction, code reusability, inheritance and polymorphism principles.
# It uses the concept of classes and objects to perform functions or tasks and Logics.

# %% [markdown]
# Ans 2: In OOP, class is a blueprint for creating objects. It defines a structure that encapsulates data (attributes) and behavior (methods) that the objects created from the class will have. Class is ike a model or a blueprint and an object is an instance of it. Classes help make code modular, reusable, and organized — core benefits of OOP. Class consists of:
#
# 1. Attributes: Variables that hold the data or state of an object.
#
# 2. Methods: Functions that define the behaviors or actions that objects can perform.
#
# 3. Encapsulation: Classes help in bundling data and functions together, keeping the code organized and secure.

# %% [markdown]
# Ans 3: In Object-Oriented Programming (OOP), an object is an instance of a class. It is a fixed entity and uses the methods defined in the class to execute certain operations or tasks.
# You can create multiple objects from the same class, each with its own data.
#
# Objects are central to how OOP models real-world things in software.
#
# For example:
# Class: Car (defines properties like color, speed and methods like start, stop) Object: A specific car like a red Toyota moving at 60 km/h

# %% [markdown]
# Ans 4: Encapsulation is the concept of bundling data and methods that operate on that data within a single unit (i.e., a class), and restricting direct access to some of the object's internal components. The goal is to protect the internal state of an object and allow access only through well-defined interfaces (usually methods) whereas Abstraction is a fundamental concept in OOP that means hiding the internal implementation details and showing only the essential features of an object. It helps reduce complexity by allowing you to focus on what an object does, not how it does it.
#
# Encapsulation helps in hiding the internal data and restricting access whereas Abstraction hides the internal implementation details of an object.
#
# Encapsulation protects the object state and provides controlled access whereas Abstarction helps to simplify complexity by exposing only relevant parts

# %% [markdown]
# Ans 5: Dunder methods (short for Double UNDERscore methods), also known as magic methods or special methods, are built-in methods in Python classes that start and end with double underscores, like __init__, __str__, or __len__.
#
# They are used to customize the behavior of your objects for built-in operations (e.g., printing, addition, comparison, etc.).

# %% [markdown]
# Ans 6: Inheritance is a core concept in OOP that allows a class (called the child or subclass) to inherit properties and behaviors (i.e., attributes and methods) from another class (called the parent or superclass). This promotes code reuse, hierarchical relationships, and modularity. It also supports Polymorphism
#
# Inheritance can be used for the following:
#
# Avoid code repetition by reusing common functionalities
#
# Create specialized classes that extend general ones.
#
# Maintain a clean and scalable structure.
#
# For example: Think of a "Vehicle" class with attributes like speed and color.
# You can create "Car", "Bike", and "Truck" subclasses that inherit these attributes and add their own specific behaviors (like open_trunk() for cars).
#
# **Parent class**:-
#
# This is the base class from which other classes inherit.
# It contains attributes and methods that the child class can reuse.
#
# **Child Class**:
#
# This is the derived class that inherits from the parent class.
# Syntax for inheritance is class ChildClass(ParentClass).
# Child class automatically gets all attributes and methods of the parent class unless overridden.

# %% [markdown]
# Ans 7: Polymorphism in OOP is the ability to use the same method name in different classes or contexts. Polymorphism means “many forms”, and in OOP it refers to the ability of different classes to respond to the same method name in different ways. It allows you to write flexible and reusable code by using a common interface for objects of different types.

# %% [markdown]
# Ans 8: Encapsulation is the concept of hiding the internal state of an object and restricting direct access to it. This helps protect data from unintended modification and enforces controlled interaction through methods. Encapsulation lets you hide implementation details and expose only what's necessary through methods—helping make your code safer, more maintainable, and secure.
# In Python, encapsulation is achieved using:
#
# Public members– accessible from anywhere
#
# Protected members – indicated by a single underscore _ (convention only)
#
# Private members – indicated by a double underscore __ (name mangling for true restriction)

# %% [markdown]
# Ans 9: In Python, a constructor is a special method used to initialize objects when a class is created. It's automatically called when you create a new instance of a class. It is in Python is defined using the __init__ method.It is automatically invoked when an object of the class is instantiated. It is commonly used to set initial values for object attributes.

# %% [markdown]
# Ans 10: **Class Method**: The purpose of the Class method is to operate on the class itself, not instances. It can access and modify class-level attributes and receives the class (cls) as its first argument.
#
# **Static Method**: The Static method does not depend on instance or class.Works like a regular function, but lives inside the class namespace. Used for utility/helper functions.

# %% [markdown]
# Ans 11: Method overloading refers to the ability to define multiple methods with the same name but different numbers or types of parameters. While many programming languages like Java or C++ support true method overloading, Python does not support it in the traditional way. In Python, if you define multiple methods with the same name in a class, the last one will override the previous definitions. However, Python can simulate method overloading by using default arguments, variable-length arguments (*args, **kwargs), or by checking argument types inside the method. This allows a single method to behave differently based on the number or types of arguments passed. Though not strict overloading, it still provides flexibility to define versatile methods within classes.

# %% [markdown]
# Ans 12: Method overriding is an important concept in Object-Oriented Programming (OOP) that allows a subclass (child class) to provide a specific implementation of a method that is already defined in its superclass (parent class). The overridden method in the subclass has the same name, parameters, and signature as the method in the parent class. This allows the subclass to customize or completely change the behavior of the inherited method.
#
# Method Overriding is done to enable runtime polymorphism and to modify or extend the functionality of the base class. To ensure that the correct method is called depending on the object type, even when using a reference to the parent class.
#
# Rules for Method overriding are:
# 1. The method must have the same name as in the parent class.
#
# 2. It must have the same number and type of parameters.
#
# 3. It must be defined within the child class.
#
# 4. You can still call the parent class’s version using super().
#
# Method overriding is crucial for extensibility and flexibility in OOP. It allows subclasses to customize behavior while still leveraging existing code.

# %% [markdown]
# Ans 13: The Property decorator in Python is used to turn a method into a “read-only” attribute. It allows you to access a method like an attribute, without calling it explicitly with parentheses.
# This is particularly useful when you want to hide the implementation details of a class attribute (encapsulation) and compute or control its value while still allowing limited access. It makes a method behave like a read-only attribute
#
# They are used to encapsulate instance variables and to create read-only attributes. To make getter/setter logic more elegant and Pythonic and to keep class interfaces clean and intuitive.

# %% [markdown]
# Ans 14: Polymorphism is a fundamental principle of OOP that allows objects of different classes to be treated as objects of a common superclass. It enables a single interface to represent different types of behaviors, which improves the flexibility and scalability of systems.
#
# It provides code reusability and generalization of code i.e., same code can be used and operated on objects of different classes without modification.
#
# Polymorphism also improves extensibility by adding new classes with minimum impact on existing code. Polymorphism is essential in OOP because it promotes a design where different classes can be used interchangeably, simplifies code, supports flexible behavior, and enables systems to grow and evolve efficiently. It plays a critical role in writing clean, scalable, and maintainable object-oriented applications.

# %% [markdown]
# Ans 15: An abstract class in Python is a class that cannot be instantiated directly and is designed to be a base class for other classes. It may contain abstract methods, which are methods declared but not implemented in the abstract class. These methods must be implemented in any subclass that inherits from the abstract class.
#
# Python supports abstract classes through the abc (Abstract Base Classes) module.
# Abstract classes are used to define a common interface for a group of related classes.
# They help enforce a contract that all subclasses must follow.
# Abstract classes cannot create objects directly.
# They are defined using ABC (Abstract Base Class) and @abstractmethod decorator from the abc module.

# %% [markdown]
# Ans 16: OOP provides a language for modelling and designing complex problems by using classes and objects.
#
# Advantages of OOP are:-
#
# 1. Modular codes organized into classes and objects, which represent real world entities. Each class is self-contained, making the codebase easier to navigate and manage.
# 2. Codes are reusable, once the codes are written in a class they can be reused across multiple programs or within the same program in different classes. Inheritance allows new classes to use properties and methods of existing ones without rewriting code.
# 3. Provides Encapsulation, Data and functions that operate on data are bundled together, protecting internal state and reducing complexity. It helps in hiding the internal implementation and exposing only what is necessary.
# 4. Provides abstraction by helping to focus on what an object does instead of how it does it. Complex logic can be hidden behind simple interfaces, making the system easier to understand.
# 5. Inheritance, allowing child classes to inherit the properties and functions from the parent classes. Encourages code reuse and establishes a hierarchical relationship between classes.
# 6. Polymorphism, enables objects of different types to be treated through a common interface. Promotes flexibility and extensibility in code, allowing the same operation to behave differently on different classes.

# %% [markdown]
# Ans 17: Class variable is a variable hat is shared by all instances of a class whereas Instance variable is a variable that is unique to each instance.
#
# Class variable is declared inside the class but outside any instance method whereas Instance variable is declared Inside the class, within an instance method (usually __init__).
#
# Class variable is shared across all objects of the class whereas Instance variable is accessible only through the specific object (instance).

# %% [markdown]
# Ans 18: Multiple inheritance is a feature in Python where a class can inherit attributes and methods from more than one parent class. This means a child class can combine the functionality of multiple base classes into a single class.
# In Multiple Inheritance, the child class inherits all accessible members from both parent classes. If both parents have a method with the same name, Python uses the Method Resolution Order (MRO) to decide which one to use. Multiple Inheritance is used only when necessary, and when the design clearly benefits from combining multiple independent behaviors or features.
# The derived (child) class gets access to all the attributes and methods of the parent classes. Python resolves method conflicts using the Method Resolution Order (MRO). Python supports multiple inheritance natively (unlike some other languages like Java).

# %% [markdown]
# Ans 19: In Python, the __str__ and __repr__ methods are special (dunder) methods used to define how an object is represented as a string.
#
# __Str__ Method:-
#
# The __str__ method is called by the built-in str() function or when you print an object.
# It is meant to return a readable, user-friendly string representation of the object.
# Its goal is to be informal and useful for end users.
#
# __Repr__ Method:-
#
# The __repr__ method is called by the built-in repr() function or in interactive sessions (e.g., in the console).
# It should return a formal string representation that is unambiguous and referably something that can be used to recreate the object.
# Its goal is for developers and debugging.

# %% [markdown]
# Ans 20: In Python, the super() function is used to call methods from a parent (or superclass) in a child (or subclass). It provides a way to access inherited methods without explicitly naming the parent class, making code more maintainable and extensible, especially in the context of inheritance and method overriding.
#
# **Purpose of super()**:
#
# To call a method from the parent class inside the child class.
#
# To ensure that the parent class's __init__() or other methods are correctly executed.
#
# To support multiple inheritance cleanly by automatically resolving the method resolution order (MRO). So, super() is essential for clean, maintainable, and scalable object-oriented code in Python.
#
# **Benefits**:
#
# Avoids hardcoding the parent class name, which improves code reusability.
#
# Makes the code easier to update and maintain.
#
# Helps in cooperative multiple inheritance by ensuring each class in the hierarchy is initialized properly.

# %% [markdown]
# Ans 21:  In Python, the __del__ method is a special (dunder) method called a destructor. It is automatically invoked when an object is about to be destroyed—that is, when there are no more references to it, and it is about to be garbage collected.
#
# The purpose of the __del__ method is to perform clean-up actions before the object is removed from memory.
#
# Common use cases include:
#
# Closing files or network connections.
#
# Releasing system resources.
#
# Logging object deletion.
#
# __del__ should be used cautiously because because in comples programs it may not be called at all and error in __del__ are not raised.

# %% [markdown]
# Ans 22: Difference between @staticmethod and @classmethod in Python:-
# In Python, Staticmethod and Classmethod are both decorators used to define methods that don't behave like regular instance methods, but they serve different purposes:
#
# Staticmethod:
#
# 1. Does not take self or cls as the first argument.
#
# 2. It doesn’t access or modify class or instance data.
#
# 3. Behaves just like a regular function, but belongs to the class’s namespace.
#
# Use Case:
#
# When a method performs a function related to the class, but does not require access to the class or instance itself.
#
# Classmethod:-
#
# 1. Takes cls as the first parameter (not self).
#
# 2. Can access and modify class variables.
#
# 3. Bound to the class, not the instance.
#
# Use Case:
#
# When you need to access or modify the class state or when creating factory methods.

# %% [markdown]
# Ans 23: In Python, polymorphism with inheritance allows objects of different classes related by inheritance to be treated as objects of a common superclass, while still behaving according to their own class's implementation of a method. This enables method overriding, where a subclass provides a specific implementation of a method that is already defined in its parent class.
#
# It works when Base class defines a method and Subclasses override that method with their own version. When a method is called on an object, regardless of its specific class, Python determines at runtime which method to execute based on the object’s actual class, not the reference type.
#
# Inheritance provides a hierarchy.
#
# Polymorphism ensures that the correct method is executed, even if the object is referenced via a superclass.

# %% [markdown]
# Ans 24: Method Chaining in Python OOP is a programming technique where multiple method calls are chained together in a single line by having each method return the object itself (usually self). This allows for writing more fluent, readable, and compact code.
#
# In Object-Oriented Programming, it worrks when a method returns self, it gives back the current object instance. This allows the next method to be called on the same object immediately.

# %% [markdown]
# Ans 25: he __call__() method in Python is a special or “dunder” method that allows an instance of a class to be called like a function. It gives objects function-like behavior, meaning you can “call” them directly using parentheses () — just like you would with a regular function. This is often used in:
# 1. Function objects (also called callables)
# 2. Decorators
# 3. Custom behavior like caching, logging, or command pattern implementation
#
# __call__() makes instances callable. It bridges the gap between object-oriented and functional programming styles in Python. It can enhance readability, design flexibility, and expressiveness of code.

# %% [markdown]
# #Practical Questions

# %% [markdown]
# Ans 1:

# %%
# Code to create a parent class Animal with a method speak() that prints a generic message
# Parent class
class Animal:
    def speak(self):
        print("Animal speaks in a generic way.")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Create instances
generic_animal = Animal()
dog = Dog()

# Call the speak method on each
generic_animal.speak()
dog.speak()
# Out:
# Animal speaks in a generic way.
# Bark!

# %% [markdown]
# Ans 2:

# %%
# Program to create an abstract class Shape with a method area() and derive classes Circle and Rectangle from it, implement area() as amethod
from abc import ABC, abstractmethod
import math

# Abstract base class
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass  # Abstract method, must be implemented in subclasses

# Derived class: Circle
class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Derived class: Rectangle
class Rectangle(Shape):

    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Testing the classes
circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Area of Circle: {circle.area():.2f}")
print(f"Area of Rectangle: {rectangle.area()}")
# Out:
# Area of Circle: 78.54
# Area of Rectangle: 24

# %% [markdown]
# Ans 3:

# %%
#Program to implement multi-inheritance using a class vehicle and creating its attribute type then deriving out classes car and electric car to add an
#attribute battery to it
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def show_type(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# First derived class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def show_brand(self):
        print(f"Car Brand: {self.brand}")

# Second derived class (multi-level inheritance)
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def show_battery(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Test the multi-level inheritance
tesla = ElectricCar("Four-Wheeler", "Tesla", 85)

# Calling methods
tesla.show_type()       # From Vehicle
tesla.show_brand()      # From Car
tesla.show_battery()    # From ElectricCar
# Out:
# Vehicle Type: Four-Wheeler
# Car Brand: Tesla
# Battery Capacity: 85 kWh

# %% [markdown]
# Ans 4:

# %%
#Program to demonstrate Polymorphism  by creating a base class Bird with a method fly() and deriving two child classes Sparrow and Penguin to override the
#bird class
# Base class
class Bird:
    def fly(self):
        print("Bird is flying...")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky!")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, but they can swim!")

# Function that demonstrates polymorphism
def bird_flight(bird):
    bird.fly()

# Creating objects
sparrow = Sparrow()
penguin = Penguin()

# Calling the same function with different objects
bird_flight(sparrow)
bird_flight(penguin)
# Out:
# Sparrow flies high in the sky!
# Penguins cannot fly, but they can swim!

# %% [markdown]
# Ans 5:

# %%
#Code to demonstrate Encapsulation using class Bank Account with private attributes balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    # Public method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ₹{amount}")
        else:
            print("Deposit amount must be positive.")

    # Public method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ₹{amount}")
        else:
            print("Insufficient balance or invalid amount.")

    # Public method to check balance
    def check_balance(self):
        print(f"Current Balance: ₹{self.__balance}")


# Example usage:
account = BankAccount(1000)  # Create account with ₹1000 initial balance

account.deposit(500)
account.withdraw(300)
account.check_balance()
# Out:
# Deposited ₹500
# Withdrew ₹300
# Current Balance: ₹1200

# %% [markdown]
# Ans 6:

# %%
# Program to dntemonstrate runtime polymorphism using a method play() in a base class Instrument and derive classes Guitar and Piano using their own method
#play
# Base class
class Instrument:
    def play(self):
        print("Playing an instrument")

# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar")

# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Playing the piano")

# Function that accepts any Instrument and calls play()
def perform(instrument):
    instrument.play()

# Example usage
g = Guitar()
p = Piano()

perform(g)
perform(p)
# Out:
# Strumming the guitar
# Playing the piano

# %% [markdown]
# Ans 7:
